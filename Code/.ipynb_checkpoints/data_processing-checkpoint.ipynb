# %%
import pandas as pd

# %%
df = pd.read_csv("../Tous votes Constituante - Sheet1.csv")
df.iloc[0]
# Out:
# Unnamed: 0                                                          13
# filename                                  Vote _2022-10-25_19-53-1.xls
# startTime                                          2022-10-25 19:53:01
# endTime                                            2022-10-25 19:53:17
# label                   E/G chapitre 10 / Kapitel 10 Oui-Ja / Non-Nein
# affairVoteId                                            20221025195301
# meaningYes                                                    Accepter
# meaningNo                                                      Refuser
# meaningYesText                                                Accepter
# meaningNoText                                                  Refuser
# numYes                                                              91
# numNo                                                                9
# numAbst                                                              8
# affair               Vote final - Ch. 10 "Dispositions finales et t...
# section              2ème lecture - Dispositions finales et transit...
# note                                                               NaN
# warning                                                            NaN
# linkVideo                                                          NaN
# attachment           2022-09-19_2eme%20lecture%20-%20AMENDEMENTS_Fr...
# DE_meaningYesText                                            Zustimmen
# DE_meaningNoText                                              Ablehnen
# DE_affair            Schlussabstimmung - Schluss- und Übergangsbest...
# DE_section           Zweite Lesung - Schluss- und Übergangsbestimmu...
# DE_note              Soll der Verfassungsrat dem Gesamtpaket, das a...
# DE_warning                                                         NaN
# DE_attachment        2022-09-19_2.%20Lesung%20-%20ABAENDERUNGSANTRA...
# Name: 0, dtype: object

# %%
#filter the data set and only take 1ère lecture
filtered_df = df.drop(['affair','meaningYesText', 'meaningNoText', 'note', 'warning', 'linkVideo', 'attachment', 'DE_meaningYesText', 'DE_meaningNoText', 'DE_note', 'DE_affair', 'DE_section', 'DE_warning', 'DE_attachment'], axis=1)
filtered_df = filtered_df[filtered_df['section'].str.contains("1ère lecture")]
filtered_df.iloc[0]
# Out:
# Unnamed: 0                                                 23
# filename                         Vote _2021-12-9_16-34-22.xls
# startTime                                 2021-12-09 16:34:22
# endTime                                   2021-12-09 16:34:38
# label           Modif. Annexe 3 / Änderung Anhang 3 OUI / NON
# affairVoteId                                   20211209163422
# meaningYes                                           Accepter
# meaningNo                                             Refuser
# numYes                                                     93
# numNo                                                       1
# numAbst                                                     3
# section                              1ère lecture - Structure
# Name: 478, dtype: object

# %%
filtered_df['art_id'] = filtered_df['label'].apply(lambda x: x.rsplit(' ')[0])
filtered_df.head()
# Out:
#      Unnamed: 0                      filename            startTime  \
# 478          23  Vote _2021-12-9_16-34-22.xls  2021-12-09 16:34:22
# 479          21   Vote _2021-12-9_16-31-7.xls  2021-12-09 16:31:07
# 480          61  Vote _2021-12-9_16-29-31.xls  2021-12-09 16:29:31
# 481          63  Vote _2021-12-9_16-28-59.xls  2021-12-09 16:28:59
# 482          67  Vote _2021-12-9_16-17-43.xls  2021-12-09 16:17:43
#
#                  endTime                                          label  \
# 478  2021-12-09 16:34:38  Modif. Annexe 3 / Änderung Anhang 3 OUI / NON
# 479  2021-12-09 16:31:23          Chap.9/Kap.9: A-R09.09 – AC OUI / NON
# 480  2021-12-09 16:29:47   Chap.8/Kap.8: A-R08.08 – G. Schmid OUI / NON
# 481  2021-12-09 16:29:15          Chap.8/Kap.8: A-R08.07 – AC OUI / NON
# 482  2021-12-09 16:17:59         Chap.6/Kap.6: A-R06.04 – VLR OUI / NON
#
#        affairVoteId meaningYes meaningNo  numYes  numNo  numAbst  \
# 478  20211209163422   Accepter   Refuser      93      1        3
# 479  20211209163107   Accepter   Refuser      35     61        5
# 480  20211209162931   Accepter   Refuser      20     78        5
# 481  20211209162859   Accepter   Refuser      29     70        1
# 482  20211209161743   Accepter   Refuser      56     39        2
#
#                       section         art_id
# 478  1ère lecture - Structure         Modif.
# 479  1ère lecture - Structure  Chap.9/Kap.9:
# 480  1ère lecture - Structure  Chap.8/Kap.8:
# 481  1ère lecture - Structure  Chap.8/Kap.8:
# 482  1ère lecture - Structure  Chap.6/Kap.6:

# %%
filtered_df.size
# Out:
# 7280

# %%
#Check this part !!!!!!!!!
filtered_df = filtered_df[filtered_df['art_id'].str[0].str.isnumeric()]

# %%
filtered_df.head()
# Out:
#      Unnamed: 0                      filename            startTime  \
# 488          55  Vote _2021-12-9_14-51-52.xls  2021-12-09 14:51:52
# 489          40   Vote _2021-12-9_14-51-0.xls  2021-12-09 14:51:00
# 490          51  Vote _2021-12-9_14-49-33.xls  2021-12-09 14:49:33
# 491          11  Vote _2021-12-9_14-48-56.xls  2021-12-09 14:48:56
# 492          24   Vote _2021-12-9_14-48-9.xls  2021-12-09 14:48:09
#
#                  endTime                                              label  \
# 488  2021-12-09 14:52:08  629a, vote 1 : Commission = A-629a.135 Carron ...
# 489  2021-12-09 14:51:16  629, vote 4 : Resultat v.3 contre A-629.134 CV...
# 490  2021-12-09 14:49:49     629, vote 3 : Commission contre résultat V/A 2
# 491  2021-12-09 14:49:12   629, vote 2 : Résultat V/A 1 contre A-629.133 AC
# 492  2021-12-09 14:48:25  629, vote 1 : A-629.131 PDCVr contre A-629.132...
#
#        affairVoteId meaningYes meaningNo  numYes  numNo  numAbst  \
# 488  20211209145152   Accepter   Refuser      50     58        6
# 489  20211209145100   Accepter   Refuser      72     37        4
# 490  20211209144933   Accepter   Refuser      47     65        3
# 491  20211209144856   Accepter   Refuser      60     51        4
# 492  20211209144809   Accepter   Refuser      70     37        7
#
#                          section art_id
# 488  1ère lecture - Commission 6  629a,
# 489  1ère lecture - Commission 6   629,
# 490  1ère lecture - Commission 6   629,
# 491  1ère lecture - Commission 6   629,
# 492  1ère lecture - Commission 6   629,

# %%
filtered_df.size
# Out:
# 6864

# %%
filtered_df = filtered_df.drop_duplicates(subset=['art_id'], keep='first')

# %%
filtered_df.head()
# Out:
#      Unnamed: 0                      filename            startTime  \
# 488          55  Vote _2021-12-9_14-51-52.xls  2021-12-09 14:51:52
# 489          40   Vote _2021-12-9_14-51-0.xls  2021-12-09 14:51:00
# 493          27  Vote _2021-12-9_12-35-32.xls  2021-12-09 12:35:32
# 497           3  Vote _2021-12-9_11-59-26.xls  2021-12-09 11:59:26
# 499          54  Vote _2021-12-9_11-43-49.xls  2021-12-09 11:43:49
#
#                  endTime                                              label  \
# 488  2021-12-09 14:52:08  629a, vote 1 : Commission = A-629a.135 Carron ...
# 489  2021-12-09 14:51:16  629, vote 4 : Resultat v.3 contre A-629.134 CV...
# 493  2021-12-09 12:35:48  628, al. 2 / Abs. 2, vote 3 : Commission (y.c....
# 497  2021-12-09 11:59:42  627, vote 2 : Commission (y.c. V/A 1) contre A...
# 499  2021-12-09 11:44:05  617, vote 6 : Commission (y.c. V/A 1-5) contre...
#
#        affairVoteId meaningYes meaningNo  numYes  numNo  numAbst  \
# 488  20211209145152   Accepter   Refuser      50     58        6
# 489  20211209145100   Accepter   Refuser      72     37        4
# 493  20211209123532   Accepter   Refuser      56     50        2
# 497  20211209115926   Accepter   Refuser      74     30        8
# 499  20211209114349   Accepter   Refuser      94     12        3
#
#                          section art_id
# 488  1ère lecture - Commission 6  629a,
# 489  1ère lecture - Commission 6   629,
# 493  1ère lecture - Commission 6   628,
# 497  1ère lecture - Commission 6   627,
# 499  1ère lecture - Commission 6   617,

# %%
ids_vote = filtered_df['affairVoteId'].to_csv('votation_ids.csv')

# %%
def political_orientation(x):
    if x == 'PDC' or x == 'SVPO' or x == 'CSPO' or x =='CVPO':
        return 'CD'
    elif x == 'VLR' or x == 'UDC':
        return 'D'
    else:
        return 'G'
def vote_transformation(x):
    if x == 'Oui/Ja':
        return 'oui'
    elif x == 'Non/Nein':
        return 'non'
    elif x == 'Abst./Enth.':
        return 'abst'
    else: 
        return 'aucun'

# %%
df1 = pd.DataFrame(['D', 'CD', 'G'])
df2 = pd.DataFrame(['oui', 'non', 'aucun', 'abst'])
orientation_df = df1.merge(df2, how='cross')
orientation_df.columns=['group', 'vote']
orientation_df.head()
# Out:
#   group   vote
# 0     D    oui
# 1     D    non
# 2     D  aucun
# 3     D   abst
# 4    CD    oui

# %%
ids_vote = filtered_df['affairVoteId']
full_votes = pd.DataFrame()
for ids in ids_vote:
    temp_df = pd.read_csv("../{}.csv".format(ids))
    #for group, vote in orientation_df.enumerate():
        
    full_votes = pd.concat([full_votes, temp_df])
temp_df = full_votes
temp_df['group'] = temp_df['group'].apply(lambda x: political_orientation(x))
temp_df['vote'] = temp_df['vote'].apply(lambda x: vote_transformation(x))
print(temp_df)
# Out:
#                     name group   vote Genre  Âge        District  \
# 0       Matteo ABÄCHERLI    CD   abst     H   33            Visp
# 1        Claudia ALPIGER     G    oui     F   32            Brig
# 2         Romano AMACKER    CD    non     H   24  Westlich Raron
# 3           Peter BÄHLER    CD    non     H   68            Goms
# 4       Gabrielle BARRAS     D    non     F   58            Sion
# ..                   ...   ...    ...   ...  ...             ...
# 125  Christelle HERITIER     D  aucun     F   36            Sion
# 126        Claude NANÇOZ     D  aucun     H   69         Conthey
# 127   Bernard OBERHOLZER     G  aucun     H   76         Monthey
# 128        Damien RABOUD     D  aucun     H   35         Monthey
# 129        Fabien THETAZ     G  aucun     H   35         Monthey
#
#        affairVoteId
# 0    20211209145152
# 1    20211209145152
# 2    20211209145152
# 3    20211209145152
# 4    20211209145152
# ..              ...
# 125  20211005101833
# 126  20211005101833
# 127  20211005101833
# 128  20211005101833
# 129  20211005101833
#
# [23140 rows x 7 columns]

# %%
ori_df = pd.DataFrame()
columns = []
for group, vote in zip(orientation_df.group, orientation_df.vote):
    ori_df[("{}, {}".format(group, vote))]=""
ori_df['affairVoteId'] = ""
ori_df.head()
# Out:
# Empty DataFrame
# Columns: [D, oui, D, non, D, aucun, D, abst, CD, oui, CD, non, CD, aucun, CD, abst, G, oui, G, non, G, aucun, G, abst, affairVoteId]
# Index: []

# %%
def add_elems(x):
    if x[1] == 'D':
        if x[2] == 'oui':
            return 'D, oui'
        elif x[2] == 'non':
            return 'D, non'
        elif x[2] == 'aucun':
            return 'D, aucun'
        else :
            return 'D, abst'
    elif x[1] == 'CD':
        if x[2] == 'oui':
            return 'CD, oui'
        elif x[2] == 'non':
            return 'CD, non'
        elif x[2] == 'aucun':
            return 'CD, aucun'
        else :
            return 'CD, abst'
    else: 
        if x[2] == 'oui':
            return 'G, oui'
        elif x[2] == 'non':
            return 'G, non'
        elif x[2] == 'aucun':
            return 'G, aucun'
        else :
            return 'G, abst'

# %%
counts_df = temp_df.groupby(['affairVoteId','group', 'vote']).size()
index = -1
art_id = 0
for ids, val in zip(counts_df.keys(), counts_df):
    temp_art_id = ids[0]
    #print("===========================")
    #print(index)
    #print("===========================")
    #print(ids)
    #print(val)
    if(art_id != temp_art_id):
        #print(ids)
        index += 1
        ori_df.at[index,'affairVoteId'] = ids[0]
        art_id = temp_art_id
        
    #if(ids[0] == 20211005101833):
    #    print("===========================")
    #    print(index)
    #    print("===========================")
     #   print(ids)
     #   print(val)
    if ids[1] =='CD':
        if ids[2] == 'oui':
            ori_df.at[index,"{}".format(add_elems(ids))] = 0.3*val/54
        elif ids[2] == 'non':
            #print(-(0.3*val/54))
            ori_df.at[index,"{}".format(add_elems(ids))] = -(0.3*val/54)
        else:
            ori_df.at[index,"{}".format(add_elems(ids))] = 0
    elif ids[1] =='G':
        if ids[2] == 'oui':
            ori_df.loc[index,"{}".format(add_elems(ids))] = -(val/41)
        elif ids[2] == 'non':
            ori_df.loc[index,"{}".format(add_elems(ids))] = val/41
    else :
        if ids[2] =='oui':
            ori_df.at[index,"{}".format(add_elems(ids))] = val*0.7/35
        elif ids[2] == 'non':
            ori_df.at[index,"{}".format(add_elems(ids))] = -(0.7*val/35)
ori_df = ori_df.fillna(0)
ori_df.head(10)
# Out:
#    D, oui  D, non  D, aucun  D, abst   CD, oui   CD, non  CD, aucun  CD, abst  \
# 0    0.36   -0.20         0        0  0.061111 -0.227778          0         0
# 1    0.52   -0.02         0        0  0.155556 -0.100000          0         0
# 2    0.38   -0.22         0        0  0.283333 -0.005556          0         0
# 3    0.24   -0.34         0        0  0.072222 -0.205556          0         0
# 4    0.38   -0.24         0        0  0.266667 -0.027778          0         0
# 5    0.30   -0.30         0        0  0.000000 -0.294444          0         0
# 6    0.04   -0.56         0        0  0.194444 -0.094444          0         0
# 7    0.40   -0.22         0        0  0.255556 -0.033333          0         0
# 8    0.36   -0.26         0        0  0.222222 -0.072222          0         0
# 9    0.26   -0.36         0        0  0.077778 -0.216667          0         0
#
#      G, oui    G, non  G, aucun  G, abst    affairVoteId
# 0 -0.460976  0.187805         0        0  20211005101833
# 1 -0.631707  0.017073         0        0  20211005103758
# 2 -0.631707  0.017073         0        0  20211005104632
# 3 -0.495122  0.085366         0        0  20211005105440
# 4 -0.648780  0.000000         0        0  20211005110548
# 5 -0.239024  0.409756         0        0  20211005113841
# 6 -0.051220  0.563415         0        0  20211005115057
# 7 -0.631707  0.000000         0        0  20211005121022
# 8 -0.563415  0.051220         0        0  20211005141356
# 9 -0.051220  0.580488         0        0  20211005144844

# %%
final_df = pd.merge(filtered_df, full_votes, on='affairVoteId')
final_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_12875/4122812186.py in <module>
# ----> 1 final_df = pd.merge(filtered_df, full_votes, on='affairVoteId')
#       2 final_df.head()
#
# ~/Anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~/Anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~/Anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1094                     if not is_rkey(rk):
#    1095                         if rk is not None:
# -> 1096                             right_keys.append(right._get_label_or_level_values(rk))
#    1097                         else:
#    1098                             # work-around for merge_asof(right_index=True)
#
# ~/Anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'affairVoteId'
